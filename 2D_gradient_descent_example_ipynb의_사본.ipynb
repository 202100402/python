# %% [markdown]
# <a href="https://colab.research.google.com/github/202100402/python/blob/main/2D_gradient_descent_example_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#202100402 권하늘_함수 그래프 그리기

import numpy as np
import matplotlib.pyplot as plt

x = np.array(range(0,3))
y = np.array([[ x**2 +np.sin(3*x+7)] for x in range(0,3)])


plt.plot(y)

# %%
#202100402 권하늘_2D gradient descent 구현 

import numpy as np
import matplotlib.pyplot as plt
#import math
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return a**3 + (1/3)* b**3 +2* np.cos(a*b)

def grad_f(a,b): # gradient
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0] # to store all thetas
	theta = theta0     # initial values for thetas
	# main loop by iterations:
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1]) #함수 f(x,y)의 gradient
		# update parameters:
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-3, -3], iters =30, alpha = 0.0003)

# f(x,y) = x^2 + y^2 함수의 그래프 그리기
fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
#plt.hold(True)
a = np.arange(-2, 2, 0.25)
b = np.arange(-2, 2, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.3, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
## c= 0 ## 최소값을 찾기 위한 부분
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

##plt.axis('equal')

plt.show()
# Out:
# [-37.82226052 -38.12185849 -38.41951227 -38.71517269 -39.00880006
#  -39.30036413 -39.58984379 -39.87722692 -40.1625101  -40.44569827
#  -40.72680449 -41.00584953 -41.28286159 -41.55787586 -41.83093422
#  -42.1020848  -42.37138168 -42.63888447 -42.90465795 -43.16877174
#  -43.43129994 -43.69232082 -43.95191646 -44.2101725  -44.46717785
#  -44.72302438 -44.97780673 -45.23162205 -45.48456983 -45.73675165
#  -45.98827107]

# %%
#202100402 권하늘_Caffeine Content of Drinks 시각화 하기

import pandas as pd
import seaborn as sns

targetUrl_iris="https://raw.githubusercontent.com/202100402/python/main/caffeine.csv"

irisData = pd.read_csv(targetUrl_iris)

print(irisData.shape)

print(irisData.head())

irisData.tail()
# Out:
# (610, 5)
#                          drink  Volume (ml)  Calories  Caffeine (mg)    type
# 0                 Costa Coffee   256.993715         0            277  Coffee
# 1  Coffee Friend Brewed Coffee   250.191810         0            145  Coffee
# 2           Hell Energy Coffee   250.191810       150            100  Coffee
# 3           Killer Coffee (AU)   250.191810         0            430  Coffee
# 4                 Nescafe Gold   250.191810         0             66  Coffee
#                          drink  Volume (ml)  Calories  Caffeine (mg)   type
# 605   Pep Talk Sparkling Water      354.882         0             55  Water
# 606        Polar Seltzer Water      354.882         0              0  Water
# 607     Yerbae Sparkling Water      354.882         0            100  Water
# 608                Tonic Water      295.735       110              0  Water
# 609  MiO Energy Water Enhancer      236.588         0             60  Water
